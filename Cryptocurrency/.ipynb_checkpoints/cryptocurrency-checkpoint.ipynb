# %%
# Get bitcoin data from GeckoAPI
from pycoingecko import CoinGeckoAPI
from datetime import datetime 

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import os

# %%
cg = CoinGeckoAPI()

# %%
# Get previous prices (1 yr + 1 day)
data = cg.get_coin_market_chart_by_id(id='bitcoin', vs_currency='usd', days='366', interval='daily')
data

# %%
# keys of data dictionary.
data.keys()
# Out:
# dict_keys(['prices', 'market_caps', 'total_volumes'])

# %%
# Create Bitcoin data frame based on the dictionary from cg api.
bitcoin_df = pd.DataFrame()

bitcoin_df['Date'] = pd.DataFrame(data['prices'])[0]
bitcoin_df['Price'] = pd.DataFrame(data['prices'])[1]
bitcoin_df['Total_Vols'] = pd.DataFrame(data['total_volumes'])[1]
bitcoin_df['Market Cap'] = pd.DataFrame(data['market_caps'])[1]

bitcoin_df
# Out:
#               Date     Price        Total_Vols         Market Cap
# 0    1591315200000  9,776.20 24,903,069,188.40 179,830,985,954.85
# 1    1591401600000  9,636.97 23,447,982,002.19 177,373,937,377.30
# 2    1591488000000  9,662.86 19,374,357,195.06 177,901,732,349.93
# 3    1591574400000  9,738.60 23,856,639,264.76 179,167,717,944.46
# 4    1591660800000  9,773.03 21,154,971,285.09 179,810,911,053.20
# ..             ...       ...               ...                ...
# 362  1622592000000 36,680.07 33,536,905,027.71 688,726,381,047.18
# 363  1622678400000 37,685.72 31,240,691,604.20 704,531,333,543.39
# 364  1622764800000 39,151.32 33,396,718,844.56 733,150,718,114.46
# 365  1622851200000 36,938.72 39,345,490,149.31 691,747,462,828.36
# 366  1622875127000 37,805.02 34,971,519,516.23 708,555,240,226.21
#
# [367 rows x 4 columns]

# %%
# Clean data format
# Unix timestamp -> utc format
bitcoin_df['Date'] = bitcoin_df['Date'].apply(lambda x: datetime.utcfromtimestamp(int(x) / 1000).strftime('%Y-%m-%d'))

# Show only 2 decimals (will not modify actual value)
pd.options.display.float_format = "{:,.2f}".format
bitcoin_df
# Out:
#            Date     Price        Total_Vols         Market Cap
# 0    2020-06-05  9,776.20 24,903,069,188.40 179,830,985,954.85
# 1    2020-06-06  9,636.97 23,447,982,002.19 177,373,937,377.30
# 2    2020-06-07  9,662.86 19,374,357,195.06 177,901,732,349.93
# 3    2020-06-08  9,738.60 23,856,639,264.76 179,167,717,944.46
# 4    2020-06-09  9,773.03 21,154,971,285.09 179,810,911,053.20
# ..          ...       ...               ...                ...
# 362  2021-06-02 36,680.07 33,536,905,027.71 688,726,381,047.18
# 363  2021-06-03 37,685.72 31,240,691,604.20 704,531,333,543.39
# 364  2021-06-04 39,151.32 33,396,718,844.56 733,150,718,114.46
# 365  2021-06-05 36,938.72 39,345,490,149.31 691,747,462,828.36
# 366  2021-06-05 37,805.02 34,971,519,516.23 708,555,240,226.21
#
# [367 rows x 4 columns]

# %%
# Create new column indicating price change from previous day
bitcoin_df['Difference'] = bitcoin_df['Price'] - bitcoin_df['Price'].shift(periods = 1)

# Fill in nan value
bitcoin_df = bitcoin_df.fillna(value=0)

# Boolean value of whether price whent up.
# 0 change is considered 'up', since there will be no loss of profit.
bitcoin_df['Up'] = bitcoin_df['Difference'].apply(lambda x: True if x >= 0 else False)

bitcoin_df
# Out:
#            Date     Price        Total_Vols         Market Cap  Difference  \
# 0    2020-06-05  9,776.20 24,903,069,188.40 179,830,985,954.85        0.00
# 1    2020-06-06  9,636.97 23,447,982,002.19 177,373,937,377.30     -139.24
# 2    2020-06-07  9,662.86 19,374,357,195.06 177,901,732,349.93       25.89
# 3    2020-06-08  9,738.60 23,856,639,264.76 179,167,717,944.46       75.74
# 4    2020-06-09  9,773.03 21,154,971,285.09 179,810,911,053.20       34.43
# ..          ...       ...               ...                ...         ...
# 362  2021-06-02 36,680.07 33,536,905,027.71 688,726,381,047.18     -660.61
# 363  2021-06-03 37,685.72 31,240,691,604.20 704,531,333,543.39    1,005.65
# 364  2021-06-04 39,151.32 33,396,718,844.56 733,150,718,114.46    1,465.60
# 365  2021-06-05 36,938.72 39,345,490,149.31 691,747,462,828.36   -2,212.60
# 366  2021-06-05 37,805.02 34,971,519,516.23 708,555,240,226.21      866.30
#
#         Up
# 0     True
# 1    False
# 2     True
# 3     True
# ...

# %%
len(bitcoin_df)
# Out:
# 367

# %%
pre_three_days_average = np.empty(shape=1)
pre_seven_days_average = np.empty(shape=1)
pre_thirty_days_average = np.empty(shape=1)
post_three_days_average = np.empty(shape=1)
post_seven_days_average = np.empty(shape=1)

for i in range(len(bitcoin_df)):
    pre_three_average = np.mean(bitcoin_df[(0 if (i-3 < 0) else i-3):i+1]['Price'])
    pre_three_days_average = np.append(pre_three_days_average, pre_three_average)
    
    pre_seven_average = np.mean(bitcoin_df[(0 if (i-7 < 0) else i-7):i+1]['Price'])
    pre_seven_days_average = np.append(pre_seven_days_average, pre_seven_average)
    
    pre_thirty_average = np.mean(bitcoin_df[(0 if (i-30 < 0) else i-30):i+1]['Price'])
    pre_thirty_days_average = np.append(pre_thirty_days_average, pre_thirty_average)
    
    post_three_average = np.mean(bitcoin_df[i:(len(bitcoin_df) if (i+3 > len(bitcoin_df)) else i+4)]['Price'])
    post_three_days_average = np.append(post_three_days_average, post_three_average)
    
    post_seven_average = np.mean(bitcoin_df[i:(len(bitcoin_df) if (i+7 > len(bitcoin_df)) else i+8)]['Price'])
    post_seven_days_average = np.append(post_seven_days_average, post_seven_average)
    
bitcoin_df["Pre 3 days Mean"] = pre_three_days_average[1:]
bitcoin_df["Pre 7 days Mean"] = pre_seven_days_average[1:]
bitcoin_df["Pre 30 days Mean"] = pre_thirty_days_average[1:]
bitcoin_df["Post 3 days Mean"] = post_three_days_average[1:]
bitcoin_df["Post 7 days Mean"] = post_seven_days_average[1:]

bitcoin_df
# Out:
#            Date     Price        Total_Vols         Market Cap  Difference  \
# 0    2020-06-05  9,776.20 24,903,069,188.40 179,830,985,954.85        0.00
# 1    2020-06-06  9,636.97 23,447,982,002.19 177,373,937,377.30     -139.24
# 2    2020-06-07  9,662.86 19,374,357,195.06 177,901,732,349.93       25.89
# 3    2020-06-08  9,738.60 23,856,639,264.76 179,167,717,944.46       75.74
# 4    2020-06-09  9,773.03 21,154,971,285.09 179,810,911,053.20       34.43
# ..          ...       ...               ...                ...         ...
# 362  2021-06-02 36,680.07 33,536,905,027.71 688,726,381,047.18     -660.61
# 363  2021-06-03 37,685.72 31,240,691,604.20 704,531,333,543.39    1,005.65
# 364  2021-06-04 39,151.32 33,396,718,844.56 733,150,718,114.46    1,465.60
# 365  2021-06-05 36,938.72 39,345,490,149.31 691,747,462,828.36   -2,212.60
# 366  2021-06-05 37,805.02 34,971,519,516.23 708,555,240,226.21      866.30
#
#         Up  Pre 3 days Mean  Pre 7 days Mean  Pre 30 days Mean  \
# ...

# %%
plt.plot(bitcoin_df['Date'], bitcoin_df['Price'])
#plt.plot(bitcoin_df['Date'], bitcoin_df['Pre 3 days Mean'])
plt.plot(bitcoin_df['Date'], bitcoin_df['Pre 7 days Mean']) # Orange
plt.plot(bitcoin_df['Date'], bitcoin_df['Pre 30 days Mean']) # Green
#plt.plot(bitcoin_df['Date'], bitcoin_df['Post 3 days Mean'])
plt.plot(bitcoin_df['Date'], bitcoin_df['Post 7 days Mean']) # Red
plt.xticks(np.arange(0, len(df['Date']) - 1, 90))
plt.show()

# %%
from sklearn.linear_model import LinearRegression

for i in bitcoin_df.columns:
    if (i == "Date") | (i == "Up"):
        continue
    X = bitcoin_df[[i]]
    Y = bitcoin_df['Up']

    model = LinearRegression().fit(X, Y)
    r_sq = model.score(X, Y)

    print("Prediction based on " + i + " : ", r_sq)
    
    plt.plot(bitcoin_df['Date'], bitcoin_df['Price'])
    plt.plot(bitcoin_df['Date'], bitcoin_df[i])
    plt.xticks(np.arange(0, len(df['Date']) - 1, 90))
    plt.show()
# Out:
# Prediction based on Price :  0.002975600896238384
# Prediction based on Total_Vols :  0.011321003169213695
# Prediction based on Market Cap :  0.003067946542337663
# Prediction based on Difference :  0.3392487443233202
# Prediction based on Pre 3 days Mean :  0.0076436801943516874
# Prediction based on Pre 7 days Mean :  0.009213809647669713
# Prediction based on Pre 30 days Mean :  0.010256765898159936
# Prediction based on Post 3 days Mean :  0.0030345907862352473
# Prediction based on Post 7 days Mean :  0.0025669553626145314
